# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('D:\Techno Internship\Task 1\kc_house_data.csv')
space = data['sqft_living']
price = data['price']

x = np.array(space).reshape(-1,1)
y = np.array(price)

from sklearn.model_selection import train_test_split

xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=1/3,random_state=0)

from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(xtrain,ytrain)
pred = reg.predict(xtest)
print("The prediction is :",pred)

plt.scatter(xtrain,ytrain,color = 'red')
plt.plot(xtrain,reg.predict(xtrain),color='blue')
plt.title('Train Dataset')
plt.xlabel('Space')
plt.ylabel('Price')
plt.show()

plt.scatter(xtest,ytest,color='red')
plt.plot(xtest,reg.predict(xtest),color='blue')
plt.title('Test Dataset')
plt.xlabel('Space')
plt.ylabel('Price')
plt.show()
# Out:
# The prediction is : [ 362496.90888926 1249614.79894487  365234.92706844 ...  482969.70877335
#   288570.41805129  255714.19990108]
